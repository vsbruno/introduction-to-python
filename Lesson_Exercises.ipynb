# %% [markdown]
# ## Test
#
# Lets check to see your notebook enviornment is working. Simply run the code in the next pane and you should see the text ouput of
#
# Hello Notebook World!

# %%
print("Hello My ! Notebook World!")

# %% [markdown]
# ## Exercise 1: Variables in Python
#
# Create a variable called name and assign it the value "Alice".
# Create a variable called age and assign it the value 25.
# Print the message "My name is <name> and I am <age> years old.", where <name> and <age> are replaced by the values of the name and age variables.
# Change the value of the age variable to 26.
# Print the message "Next year, I will be <new_age> years old.", where <new_age> is the value of the age variable plus 1.

# %%
# Insert your code here

name = "Alice"
age = 26
print(name)
print("My name is ", name)
print("I am aged", age)

# %% [markdown]
# ### Exercise 2 : Data Types in Python
# Create a variable called my_int and assign it the value 10.
# Create a variable called my_float and assign it the value 3.14.
# Create a variable called my_bool and assign it the value True.
# Create a variable called my_str and assign it the value "Hello, world!".
# Print the data type of each variable using the type() function.

# %%
# Insert your code here

my_int = 10

my_float = 3.14

my_bool = True

print(type(my_int))
print(type(my_float))
print(type(my_bool))

# %% [markdown]
# ### Exercise 3: Assignment Operators in Python
#
# Create a variable called x and assign it the value 10.
# - Next use the += operator to add 5 to x and print the result.
# - Next use -= operator to subtract 2 from  and print the result.
# - Next use the *= operator to multiply x by 3 and print the result.
# - Next use the /= operator to divide x by 2 and print the result.
# - Use the %= operator to get the remainder of x divided by and print the result.

# %%
# Insert your code here

x = 10
x += 5
print(x)

# %% [markdown]
# ## Exercise 4: If statement
#
# Write a program that defines a variable pet and assigns it a string value representing a type of pet, such as "cat", "dog", or "hamster". The program should then check if the pet is a cat, and print a message saying "I love cats!" if it is.

# %%
# Insert your code here

# %% [markdown]
# ### Results explained
#
# I love cats!
#
# In this exercise, we define a variable pet and assign it the value "cat". We then use an if statement to check if pet is equal to the string "cat". Since the condition is true (i.e., pet does equal "cat"), the program prints the message "I love cats!"

# %% [markdown]
# ## Exercise 5: For loop
#
# Write a program that defines a list of strings representing different types of pets, such as "cat", "dog", and "hamster". The program should then use a for loop to iterate over the list and print a message for each pet, saying "I have a <pet>!".
#
# hint: you can define the list as: pets = ["cat", "dog", "hamster"]

# %%
# Insert your code here

# %% [markdown]
# ### Results explained
#
# I have a cat
# I have a dog
# I have a hamster
#
# In this exercise, we define a list of pets called pets, which contains the strings "cat", "dog", and "hamster". We then use a for loop to iterate over the list and print a message for each pet, saying "I have a <pet>!". The loop variable pet takes on the value of each element in the list in turn, allowing us to access and print each pet's name.

# %% [markdown]
# ## Exercise 6: While loop
#
# Write a program that defines a variable count and assigns it a value of 5. The program should then use a while loop to print the numbers from count down to 1 on separate lines.

# %%
# Insert your code here

# %% [markdown]
# ### Results explained
#
# 5
# 4
# 3
# 2
# 1
#
# In this exercise, we define a variable count and assign it the value 5. We then use a while loop to print the numbers from count down to 1 on separate lines. The loop condition checks if count is greater than 0, and as long as it is, the loop executes the code block inside the loop, which prints the value of count and decrements it by 1. This process repeats until count reaches 0, at which point the loop terminates and the program stops executing.

# %% [markdown]
# ## Exercise 7: Lists
#
# Suppose you are given a list of car makes. Your task is to print each car make one by one.
#
# Instructions:
#
# - Create a list named car_makes and add 5 car makes to the list.
# - The car makes are 'Toyota', 'Honda', 'Ford', 'Chevrolet', 'Nissan'  Tip; these are strings and thus the quotes ;)
# - Use a for loop to iterate over the list and print each car make on a new line.   Tip: Because this is a list use both **for** and **in**

# %%
# Insert your code here

# %% [markdown]
# ### Results explained
#
# In this exercise we defined a list called car_makes and provided a set of car makes. Next we itereated over the list (or collection) using a **for** loop. The loop variable car_make takes on the value of each element in the list in turn, allowing us to access and print each car_make's name to provide the following output.
#
#
# - Toyota
# - Honda
# - Ford
# - Chevrolet
# - Nissan

# %% [markdown]
# ## Exercise 8: Dictionary
#
#  Create a Python dictionary named car_models that contains key-value pairs of car makes and their corresponding models.
#
# - Use at least five different car makes and models in your dictionary as shown below ( car make = key, car model = value).
#
#     -    "Honda": "Civic",
#     -    "Toyota": "Corolla",
#     -    "Ford": "Mustang",
#     -    "Chevrolet": "Camaro",
#     -     "BMW": "M3"
#
#
# - Next, use 3 seperate print statements to  print at least 3 car models  using the car make as the key
#
# Finally, call the print_car_models function and pass in the car_models dictionary you created.

# %%
# Insert your code here

# %% [markdown]
# ### Results explained
#
# In this modified exercise, we directly created a dictionary with car makes as keys and car models as values. We then accessed the values of the keys directly by using the key in square brackets to retrieve the corresponding value. The output of this code should be:
#
# - Civic
# - Mustang
# - M3

# %% [markdown]
# # Exercise 9:  Included in Lesson

# %% [markdown]
# ## Excercise 10
#
# Lets use the python standard library os mudule to manipultea file.
#
# - Step 1: open the file for writing
# - Step 2: Write "Hello World" to the file
# - Step 3: Write "Welcome to Pytho"n to the file
# - Step 4: Close the file
# - Step 5: Open the file again but this time for reading
# - Step 6: Assign the contents of the file to a variable called data
# - Step 7: Print the variable data

# %%
# Insert your code here
